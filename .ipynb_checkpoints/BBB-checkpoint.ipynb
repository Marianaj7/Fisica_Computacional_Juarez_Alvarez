# %% [markdown]
# # Caminatas cuánticas aleatorias: Caso clásico

# %% [markdown]
# El modelo básico de las caminatas aleatorias es el movimiento de una partícula (llamado caminante) sobre puntos discretos distribuidos en una línea sin restricciones. El sentido del movimiento del caminante (izquierda o derecha) depende de un
# sistema bivaluado (una moneda), cuyos valores, para cada paso, dependen de la probabilidad. Si el resultado del voltado es sol(o bien 1, en nuestro caso), entonces el caminante dará un paso a la derecha, mientras que si cae águila (-1) el caminante hará lo contrario, y dará un paso hacia la izqierda. Cabe mencionar que durante todo el problema, el caminante partirá de un punto de inicio, cuyo valor será 0.  Después de muchos volados (digamos, cien), uno puede hacer varias preguntas interesantes, por ejemplo: ¿con qué frecuencia el caminante cae en la posición de inicio?

# %%
using PyPlot

# %%
#La rutina que se presenta a continuación es una recopilación  de diversas funciones. El input (n) corresponde al número de volados que se desea realizar.
function posicion_final(n)
    b=rand(-1:2:1,n)     #Usamos la función rand para generar valores aleatorios, éstos sólo podrán ser 1 (sol) y -1 (águila).
    p=0
    for i in 1:length(b)
    p=b[i]+p  #Se implementa un for para, una vez generados todos los valores de los volados, obtener la posición final del caminante, esto es simplemente la suma de todos ellos.
end
return p  #Finalmente, el valor p corresponde a la posición final del caminante después de n pasos.
end
# Out:
# WARNING: Method definition posicion_final(Any) in module Main at In[142]:3 overwritten at In[166]:3.
# posicion_final (generic function with 1 method)

# %%
#Sin embargo, a nosotros nos interesa hacer un análisis para  K número de caminantes. Ahora le pedimos al usuario tanto el número de volados "n", como el de caminantes "k"
function pf_caminantes(n,k) 
    listf=zeros(k)  # Construimos una lista con k entradas de ceros 
    for i in 1:k  #Este ciclo for se usa para encontrar la posición final de los k caminantes haciendo uso de la función de posicion_final (presentada anteriormente)
        d=posicion_final(n)
        listf[i]=d  
        end 
    return listf # Se imprime la lista con la posición final de los k caminantes.
    end
# Out:
# WARNING: Method definition pf_caminantes(Any, Any) in module Main at In[143]:3 overwritten at In[167]:3.
# pf_caminantes (generic function with 1 method)

# %%
#Se implementa la función pf_caminantes para 10 volados y mil caminantes, a la cual llamaremos "CA"
CA=pf_caminantes(10,1000);

# %%
hist(pf_caminantes(10,1000))
# Out:
# WARNING: hist(...) and hist!(...) are deprecated. Use fit(Histogram,...) in StatsBase.jl instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in #hist!#1014(::Bool, ::Function, ::Array{Int64,1}, ::Array{Float64,1}, ::FloatRange{Float64}) at ./deprecated.jl:630
#  in hist(::Array{Float64,1}) at ./deprecated.jl:647
#  in include_string(::String, ::String) at ./loading.jl:441
#  in include_string(::Module, ::String, ::String) at /home/juser/.julia/v0.5/Compat/src/Compat.jl:478
#  in execute_request(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:154
#  in invokelatest(::Function, ::ZMQ.Socket, ::Vararg{Any,N}) at /home/juser/.julia/v0.5/Compat/src/Compat.jl:489
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/eventloop.jl:8
#  in (::IJulia.##18#24)() at ./task.jl:360
# while loading In[169], in expression starting on line 1
# (-10.0:2.0:10.0,[13,50,111,185,260,222,99,44,11,5])

# %%
A=ans[2]
# Out:
# 10-element Array{Int64,1}:
#   13
#   50
#  111
#  185
#  260
#  222
#   99
#   44
#   11
#    5

# %%
plot(ans)
title("Distribución de frecuencias para mil caminantes y diez volados")
ylabel("Frecuencia"); 
xlabel("Posición");
legend()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7efdd2131890>)

# %%
PA= A[1]/1000,A[2]/1000,A[3]/1000,A[4]/1000,A[5]/1000,A[6]/1000,A[7]/1000,A[8]/1000,A[9]/1000,A[10]/1000
P=-10,-8,-6,-4,-2,0,2,4,6,8
plot(P,PA)
title("Distribución de probabilidad para mil caminantes y diez volados")
ylabel("Probabilidad"); 
xlabel("Posición");
legend()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7efdd2069c50>)

# %%
hist(pf_caminantes(10,10000))
# Out:
# WARNING: hist(...) and hist!(...) are deprecated. Use fit(Histogram,...) in StatsBase.jl instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in #hist!#1014(::Bool, ::Function, ::Array{Int64,1}, ::Array{Float64,1}, ::FloatRange{Float64}) at ./deprecated.jl:630
#  in hist(::Array{Float64,1}) at ./deprecated.jl:647
#  in include_string(::String, ::String) at ./loading.jl:441
#  in include_string(::Module, ::String, ::String) at /home/juser/.julia/v0.5/Compat/src/Compat.jl:478
#  in execute_request(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:154
#  in invokelatest(::Function, ::ZMQ.Socket, ::Vararg{Any,N}) at /home/juser/.julia/v0.5/Compat/src/Compat.jl:489
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/eventloop.jl:8
#  in (::IJulia.##18#24)() at ./task.jl:360
# while loading In[173], in expression starting on line 1
# (-12.0:2.0:10.0,[12,99,428,1189,2039,2499,2024,1201,410,89,10])

# %%
B=ans[2];

# %%
plot(ans)
title("Distribución de frecuencia para diez mil caminantes y diez volados")
ylabel("Frecuencia"); 
xlabel("Posición");
legend()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7efe02681f10>)

# %%
PB= B[1]/10000,B[2]/10000,B[3]/10000,B[4]/10000,B[5]/10000,B[6]/10000,B[7]/10000,B[8]/10000,B[9]/10000,B[10]/10000
P=-10,-8,-6,-4,-2,0,2,4,6,8
plot(P,PB)
title("Distribución de probabilidad para diez mil caminantes y diez volados")
ylabel("Probabilidad"); 
xlabel("Posición");
legend()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7efdd29c7b10>)

# %%
hist(pf_caminantes(10,100000))
# Out:
# WARNING: hist(...) and hist!(...) are deprecated. Use fit(Histogram,...) in StatsBase.jl instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in #hist!#1014(::Bool, ::Function, ::Array{Int64,1}, ::Array{Float64,1}, ::FloatRange{Float64}) at ./deprecated.jl:630
#  in hist(::Array{Float64,1}) at ./deprecated.jl:647
#  in include_string(::String, ::String) at ./loading.jl:441
#  in include_string(::Module, ::String, ::String) at /home/juser/.julia/v0.5/Compat/src/Compat.jl:478
#  in execute_request(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:154
#  in invokelatest(::Function, ::ZMQ.Socket, ::Vararg{Any,N}) at /home/juser/.julia/v0.5/Compat/src/Compat.jl:489
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/eventloop.jl:8
#  in (::IJulia.##18#24)() at ./task.jl:360
# while loading In[177], in expression starting on line 1
# (-12.0:2.0:10.0,[105,983,4277,11762,20775,24441,20442,11649,4428,1042,96])

# %%
C=ans[2];

# %%
plot(ans)
title("Distribución de frecuencia para cien mil caminantes y diez volados")
ylabel("Frecuencia"); 
xlabel("Posición");
legend()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7efdd21851d0>)

# %%
PC= C[1]/100000,C[2]/100000,C[3]/100000,C[4]/100000,C[5]/100000,C[6]/100000,C[7]/100000,C[8]/100000,C[9]/100000,C[10]/100000
P=-10,-8,-6,-4,-2,0,2,4,6,8
plot(P,PC)
title("Distribución de probabilidad para diez mil caminantes y diez volados")
ylabel("Probabilidad"); 
xlabel("Posición");
legend()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7efdd27f4790>)

# %%
hist(pf_caminantes(20,1000000))
# Out:
# WARNING: hist(...) and hist!(...) are deprecated. Use fit(Histogram,...) in StatsBase.jl instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in #hist!#1014(::Bool, ::Function, ::Array{Int64,1}, ::Array{Float64,1}, ::FloatRange{Float64}) at ./deprecated.jl:630
#  in hist(::Array{Float64,1}) at ./deprecated.jl:647
#  in include_string(::String, ::String) at ./loading.jl:441
#  in include_string(::Module, ::String, ::String) at /home/juser/.julia/v0.5/Compat/src/Compat.jl:478
#  in execute_request(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:154
#  in invokelatest(::Function, ::ZMQ.Socket, ::Vararg{Any,N}) at /home/juser/.julia/v0.5/Compat/src/Compat.jl:489
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/eventloop.jl:8
#  in (::IJulia.##18#24)() at ./task.jl:360
# while loading In[181], in expression starting on line 1
# (-22.0:2.0:20.0,[3,22,188,1153,4552,14993,36795,74238,120042,160368  …  159760,119636,73970,36844,14710,4655,1119,159,35,1])

# %%
D=ans[2];

# %%
plot(ans)
title("Distribución de frecuencia para un millón caminantes y veinte volados")
ylabel("Frecuencia"); 
xlabel("Posición");
legend()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7efe02601f10>)

# %%
hist(pf_caminantes(20,100000000))
# Out:
# WARNING: hist(...) and hist!(...) are deprecated. Use fit(Histogram,...) in StatsBase.jl instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in #hist!#1014(::Bool, ::Function, ::Array{Int64,1}, ::Array{Float64,1}, ::FloatRange{Float64}) at ./deprecated.jl:630
#  in hist(::Array{Float64,1}) at ./deprecated.jl:647
#  in include_string(::String, ::String) at ./loading.jl:441
#  in include_string(::Module, ::String, ::String) at /home/juser/.julia/v0.5/Compat/src/Compat.jl:478
#  in execute_request(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:154
#  in invokelatest(::Function, ::ZMQ.Socket, ::Vararg{Any,N}) at /home/juser/.julia/v0.5/Compat/src/Compat.jl:489
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/eventloop.jl:8
#  in (::IJulia.##18#24)() at ./task.jl:360
# while loading In[184], in expression starting on line 1
# (-22.0:2.0:20.0,[109,1916,18206,108725,461625,1479909,3698982,7390868,12012336,16014349  …  16015945,12012457,7391353,3697603,1478697,461848,109043,18079,1919,87])

# %%
E=ans[2];

# %%
plot(ans)
title("Distribución de frecuencia para diez millones de caminantes y veinte volados")
ylabel("Frecuencia"); 
xlabel("Posición");
legend()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7efe02506d10>)

# %%
plot(A,label="Mil caminantes y diez volados")
plot(B,label="Diez mil caminantes y diez volados")
plot(C,label="Cien mil caminantes y diez volados")
title("Distribución de frecuencia")
ylabel("Frecuencia"); 
xlabel("Posición");
legend()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7efe02566990>)
# PyObject <matplotlib.legend.Legend object at 0x7efdd285fb10>

# %%
plot(D,label="Un millón de caminantes y veinte volados")
plot(E,label="Diez millones de caminantes y veinte volados")
title("Distribución de frecuencia")
ylabel("Frecuencia"); 
xlabel("Posición");
legend()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7efdd2334110>)
# PyObject <matplotlib.legend.Legend object at 0x7efdd28cf9d0>

# %%
plot(PA,label="Mil caminantes y diez volados")
plot(PB,label="Diez mil caminantes y diez volados")
plot(PC,label="Cien mil caminantes y diez volados")
title("Distribución de probabilidad")
ylabel("Probabilidad"); 
xlabel("Posición");
legend()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7efdd29c1850>)
# PyObject <matplotlib.legend.Legend object at 0x7efdd2bb61d0>
